# %%
import IPython
from scipy.io import wavfile
import scipy.signal
import numpy as np
import matplotlib.pyplot as plt
import librosa, librosa.display 
import contextlib
import wave
import os
# %matplotlib inline

# %%
# noise x 

folder_path = '/home/kms/nlp/dataset/m_f_c'
class_name = ['children', 'male', 'female']
# children = 8000 rate 
# mlae = 16000 rate
# female = 16000 rate 

file_path = os.path.join(folder_path, class_name[2])
print(file_path)

files = os.listdir(file_path)
print("number of files in folder {}".format(len(files)))

for i, name in enumerate(files):
    files[i] = os.path.join(file_path, name)
# Out:
# /home/kms/nlp/dataset/m_f_c/female
# number of files in folder 14051

# %%
print(files[0])
# Out:
# /home/kms/nlp/dataset/m_f_c/female/146_003_0751.flac.wav

# %%
import soundfile as sf

sf.available_subtypes('wav')
#sf.available_subtypes(files[0])
# Out:
# {'PCM_16': 'Signed 16 bit PCM',
#  'PCM_24': 'Signed 24 bit PCM',
#  'PCM_32': 'Signed 32 bit PCM',
#  'PCM_U8': 'Unsigned 8 bit PCM',
#  'FLOAT': '32 bit float',
#  'DOUBLE': '64 bit float',
#  'ULAW': 'U-Law',
#  'ALAW': 'A-Law',
#  'IMA_ADPCM': 'IMA ADPCM',
#  'MS_ADPCM': 'Microsoft ADPCM',
#  'GSM610': 'GSM 6.10',
#  'G721_32': '32kbs G721 ADPCM'}

# %%
import librosa

# %%
data, rate = librosa.load('/home/kms/nlp/dataset/clean/children/F1BCH1138_002_0.wav')

print(data.shape)
print(rate)
# Out:
# (220500,)
# 22050

# %%
print(data)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
#wav_loc_01 = "/home/kms/nlp/dataset/m_f_c_add_noise/male/107_003_0075.flac.wav"
#wav_loc_02 = "/home/kms/nlp/dataset/m_f_c_add_noise/children/F1BCH1138_002.wav"

#data,sr = librosa.load(wav_loc_01, mono=True, offset=0)
#data_2, sr_2 = librosa.load(wav_loc_02, mono=True, offset=0)
import matplotlib.pyplot as plt

import IPython
from scipy.io import wavfile
import scipy.signal
import numpy as np
import matplotlib.pyplot as plt
import librosa, librosa.display 
import contextlib
import wave
# %matplotlib inline

data, rate = librosa.load('/home/kms/nlp/audio_classification/clean/Acoustic_guitar/0eeaebcb_0.wav')

print(data.shape)
print(rate)

plt.figure(figsize=(30,8))
librosa.display.waveplot(data, rate, alpha=0.5)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Waveform")
plt.show()
# Out:
# (220500,)
# 22050
