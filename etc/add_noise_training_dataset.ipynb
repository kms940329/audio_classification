# %%
import IPython
from scipy.io import wavfile
import scipy.signal
import numpy as np
import matplotlib.pyplot as plt
import librosa, librosa.display 
import contextlib
import wave
import os
# %matplotlib inline

# %%
folder_path = '/home/kms/nlp/dataset/m_f_c/'
class_path = 'male/'
file_path =  os.path.join(folder_path, class_path)
print(file_path)
files_name = os.listdir(file_path)
print(len(files_name))
# Out:
# /home/kms/nlp/dataset/m_f_c/male/
# 8107

# %%
data_tmp, rate_tmp = librosa.load(os.path.join(file_path, files_name[0]), mono=True, sr=None, offset=0)
print(os.path.join(file_path, files_name[0]))
print(data_tmp)
print(rate_tmp)
print(len(data_tmp))
print(len(data_tmp)/rate_tmp)
# Out:
# /home/kms/nlp/dataset/m_f_c/male/172_003_1470.flac.wav
# [-3.0517578e-05 -9.1552734e-05 -6.1035156e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00]
# 16000
# 113235
# 7.0771875

# %%
# noise data load

print("number of data : {}".format(len(data_tmp)))
print("rate of data : {}".format(rate_tmp))
print("length of data {} s".format(len(data_tmp)/rate_tmp))

noise_file = '/home/kms/nlp/NLP_project_v2/data_noise/sample_concat.wav'
# print(" check file existing : {}".format(os.path.isfile(noise_file)))

# extract noise ramdom part to noise file

data_noise, rate_noise = librosa.load(noise_file, mono=True, sr=None, offset=0)

print(data_noise.shape)
print(rate_noise)
print(len(data_noise)/rate_noise)

# 28224000
# 900000 / 1800000 / 2700000 / 3600000 / 4500000 / 5400000 / 6300000 / 7200000 / 8100000 / 9000000
# 9900000 / 10800000 / 11700000 / 12600000 / 13500000 / 14400000 / 15300000 / 16200000 / 17100000 / 18000000
# 18900000 / 19800000 / 20700000 / 21600000 / 22500000 / 23400000 / 24300000 / 25200000 / 26100000 / 27000000

noise_start = [ 900000 , 1800000 , 2700000 , 3600000 , 4500000 , 5400000 , 6300000 , 7200000 , 8100000 , 9000000, 
                9900000 , 10800000 , 11700000 , 12600000 , 13500000 , 14400000 , 15300000 , 16200000 , 17100000 , 18000000,
                18900000 , 19800000 , 20700000 , 21600000 , 22500000 , 23400000 , 24300000 , 25200000 , 26100000 , 27000000 ]

print(len(noise_start))

data_noise_tmp = np.random.choice(data_noise, size=0, replace=True, p=None)
# Out:
# number of data : 113235
# rate of data : 16000
# length of data 7.0771875 s
# (28224000,)
# 44100
# 640.0
# 30

# %%
save_path = '/home/kms/nlp/dataset/m_f_c_add_noise/'
save_path = os.path.join(save_path, class_path)

for count, i in enumerate(files_name):
    file_tmp = os.path.join(file_path, i)
    #print(file_tmp) # file path + file name
    #print(file_path) # file path
    #print(i) # file name
    data_tmp, rate_tmp = librosa.load(file_tmp, mono=True, sr=None, offset=0)
    noise_start_count = count % len(noise_start)
    noise_start_count = noise_start[noise_start_count]
    #print(noise_start_count) # 1800000
    #print(len(data_tmp))
    noise_end_count = noise_start_count + len(data_tmp)
    #print(noise_end_count)

    data_noise_tmp = data_noise[noise_start_count:noise_end_count]

    #print(len(data_noise_tmp))

    data_tmp = data_tmp + (data_noise_tmp*0.5)
    #print(len(data_tmp))

    librosa.output.write_wav(save_path + i,data_tmp, rate_tmp)
    #print(rate_tmp)
# Out:
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# 16000
# ...
